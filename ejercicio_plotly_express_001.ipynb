# %% [markdown]
#  # **<font color="DarkBlue">Ejercicios con Plotly Express 🐼 </font>**

# %% [markdown]
# <p align="center">
# <img src="https://plotly.com/all_static/images/graphing_library_dark.svg" width="350" height="">
# </p>

# %% [markdown]
# https://plotly.com/python/

# %% [markdown]
#  ## **<font color="DarkBlue">Consigna</font>**

# %% [markdown]
# <p align="justify">
# 💡 Generar los gráficos requeridos

# %% [markdown]
#  ## **<font color="DarkBlue">Ejercicio 1: Gráfico de Linea</font>**

# %% [markdown]
# <p><strong>Consigna:</strong> Utiliza los siguientes datos de ventas mensuales para crear un gráfico de líneas que muestre la evolución de las ventas a lo largo del año.</p>
# <ul>
#     <li><strong>Meses:</strong> ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']</li>
#     <li><strong>Ventas:</strong> [1200, 2300, 1800, 2500, 3000, 3200, 4100, 3800, 4500, 4900, 4800, 5200]</li>
# </ul>

# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.DataFrame({"Meses": ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
"Ventas": [1200, 2300, 1800, 2500, 3000, 3200, 4100, 3800, 4500, 4900, 4800, 5200]})

# %%
df
# Out:
#          Meses  Ventas
# 0        Enero    1200
# 1      Febrero    2300
# 2        Marzo    1800
# 3        Abril    2500
# 4         Mayo    3000
# 5        Junio    3200
# 6        Julio    4100
# 7       Agosto    3800
# 8   Septiembre    4500
# 9      Octubre    4900
# 10   Noviembre    4800
# 11   Diciembre    5200

# %%
fig = px.line(df,
              x="Meses",
              y="Ventas",
              title="Ventas Mensuales",
              markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df,
              x="Meses",
              y="Ventas",
              title="Ventas Mensuales",
              markers=True)

# Personalizar la línea de tendencia
fig.update_traces(marker=dict(size=10),                   # Ajustar tamaño de puntos
                  line=dict(color="royalblue", width=2))  # Color y grosor de línea de tendencia
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df,
              x="Meses",
              y="Ventas",
              title="Ventas Mensuales",
              markers=True)

# Personalizar la línea de tendencia
fig.update_traces(marker=dict(size=10),                   # Ajustar tamaño de puntos
                  line=dict(color="royalblue", width=2))  # Color y grosor de línea de tendencia

# Mejorar el diseño visual
fig.update_layout(title_font_size=20,
                  xaxis_title_font_size=14,
                  yaxis_title_font_size=14,
                  template="simple_white")  # Fondo blanco para mayor claridad
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  ## **<font color="DarkBlue">Ejercicio 2: Gráfico de Barras</font>**

# %% [markdown]
# <p><strong>Consigna:</strong> Utiliza los siguientes datos sobre las calificaciones de los estudiantes en diferentes materias para crear un gráfico de barras que compare las calificaciones promedio.</p>
# <ul>
#     <li><strong>Materias:</strong> ['Matemáticas', 'Ciencias', 'Literatura', 'Historia', 'Arte']</li>
#     <li><strong>Calificaciones:</strong> [85, 90, 78, 88, 92]</li>
# </ul>

# %%
df1 = pd.DataFrame({"Materias": ['Matemáticas', 'Ciencias', 'Literatura', 'Historia', 'Arte'],
"Calificaciones": [85, 90, 78, 88, 92]})

# %%
df1
# Out:
#       Materias  Calificaciones
# 0  Matemáticas              85
# 1     Ciencias              90
# 2   Literatura              78
# 3     Historia              88
# 4         Arte              92

# %%
px.bar(df1, x="Materias", y="Calificaciones", title="Comparación de Calificaciones")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear el gráfico de barras
fig = px.bar(df1,
             x='Materias',
             y='Calificaciones',
             title='Calificaciones por Materia',
             labels={'Materias':'Materias'},
             color='Calificaciones',  # Colorear en función del valor de ventas
             text='Materias')   # Mostrar las ventas en cada barra

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear el gráfico de barra de errores
# Crear el gráfico de barras
fig = px.bar(df1,
             x='Materias',
             y='Calificaciones',
             title='Calificaciones por Materia',
             labels={'Materias':'Materias'},
             color='Calificaciones',  # Calificaciones de las materias
             text='Materias')  ### texto de la barra


# Mejorar el diseño del gráfico
fig.update_layout(
    template="plotly_white",  # Fondo blanco para mayor claridad
    showlegend=False
)


# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  ## **<font color="DarkBlue">Ejercicio 3: Gráfico circular</font>**

# %% [markdown]
# <p><strong>Consigna:</strong> Utiliza los siguientes datos sobre la participación de mercado de diferentes marcas de automóviles para crear un gráfico de tortas que muestre la proporción de cada marca.</p>
# <ul>
#     <li><strong>Marcas:</strong> ['Toyota', 'Ford', 'Honda', 'Chevrolet', 'BMW']</li>
#     <li><strong>Participación de mercado (%):</strong> [30, 25, 20, 15, 10]</li>
# </ul>

# %%
# Crear un DataFrame de ejemplo con datos de participación de mercado de productos
data = {'Marcas': ['Toyota', 'Ford', 'Honda', 'Chevrolet', 'BMW'],
        'Participación de mercado (%)': [30, 25, 20, 15, 10]} # Participación de mercado (%): [30, 25, 20, 15, 10]]  # Cantidad de unidades de cada producto


df5 = pd.DataFrame(data)
df5
# Out:
#       Marcas  Participación de mercado (%)
# 0     Toyota                            30
# 1       Ford                            25
# 2      Honda                            20
# 3  Chevrolet                            15
# 4        BMW                            10

# %%
px.pie(df5,
       names="Marcas",
       values="Participación de mercado (%)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig =px.pie(df5,
       names="Marcas",
       values="Participación de mercado (%)",
        title='Participacion de mercado de las Marcas',
        color_discrete_sequence = px.colors.sequential.RdBu)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig =px.pie(df5,
       names="Marcas",
       values="Participación de mercado (%)",
        title='Participacion de mercado de las Marcas',
        color_discrete_sequence = px.colors.sequential.RdBu)

# Mejorar el diseño del gráfico
fig.update_traces(textposition='inside',
                  textinfo='percent+label')  # Mostrar etiquetas y porcentajes en cada sección


# Ajustar la visualización del título y estilo del gráfico
fig.update_layout(title_font_size=20,
                  template="plotly_white"   # Fondo blanco para mayor claridad
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig =px.pie(df5,
       names="Marcas",
       values="Participación de mercado (%)",
        title='Participacion de mercado de las Marcas',
        color_discrete_sequence = px.colors.sequential.RdBu,
            hole=0.4)

# Mejorar el diseño del gráfico
fig.update_traces(textposition='inside',
                  textinfo='percent+label')  # Mostrar etiquetas y porcentajes en cada sección


# Ajustar la visualización del título y estilo del gráfico
fig.update_layout(title_font_size=20,
                  template="plotly_white"   # Fondo blanco para mayor claridad
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  ## **<font color="DarkBlue">Ejercicio 4: Histograma</font>**

# %% [markdown]
# <p><strong>Consigna:</strong> Utiliza los siguientes datos sobre los precios de casas en una ciudad para crear un histograma que muestre la distribución de los precios.</p>
# <ul>
#     <li><strong>Precios de casas:</strong> [250000, 300000, 350000, 200000, 400000, 450000, 300000, 350000, 270000, 300000, 320000, 380000]</li>
# </ul>

# %%
data = ({"Precios de casas": [250000, 300000, 350000, 200000, 400000, 450000, 300000, 350000, 270000, 300000, 320000, 380000]})  # Tiempos de entrega en días


df2 = pd.DataFrame(data)
df2
# Out:
#     Precios de casas
# 0             250000
# 1             300000
# 2             350000
# 3             200000
# 4             400000
# 5             450000
# 6             300000
# 7             350000
# 8             270000
# 9             300000
# 10            320000
# 11            380000

# %%
# Crear el histograma
fig = px.histogram(df2, x='Precios de casas', nbins=25,
                   title='Precios de las casas',
                   labels={'Precios de casas': 'Precio de casas ($)'},
                   opacity=0.75)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear el histograma
fig = px.histogram(df2, x='Precios de casas', nbins=25,
                   title='Precios de las casas',
                   labels={'Precios de casas': 'Precio de casas ($)'},
                   opacity=0.75)

# Mejorar el diseño del gráfico
fig.update_layout(
    title_font_size=20,
    xaxis_title_font_size=16,
    yaxis_title_font_size=16,
    template="plotly_white",  # Fondo blanco para mayor claridad
    bargap=0.2                # Separación entre barras
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np

# %%
# Crear el histograma
fig = px.histogram(df2, x='Precios de casas', nbins=25,
                   title='Precios de las casas',
                   labels={'Precios de casas': 'Precio de casas ($)'},
                   opacity=0.75)
# Añadir línea de densidad para una mejor visualización
fig.update_traces(marker_color='cornflowerblue', marker_line_color='darkblue', marker_line_width=1)
fig.add_scatter(x=np.linspace(df2['Precios de casas'].min(), df2['Precios de casas'].max(), 100),
                y=np.exp(-0.5*((np.linspace(df2['Precios de casas'].min(), df2['Precios de casas'].max(), 100) - df2['Precios de casas'].mean()) / df2['Precios de casas'].std())**2) / (df2['Precios de casas'].std() * np.sqrt(2 * np.pi)),
                mode='lines', name='Densidad', line=dict(color='darkorange', width=2))


# Mejorar el diseño del gráfico
fig.update_layout(
    title_font_size=20,
    xaxis_title_font_size=16,
    yaxis_title_font_size=16,
    template="plotly_white",  # Fondo blanco para mayor claridad
    bargap=0.2                # Separación entre barras
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  ## **<font color="DarkBlue">Ejercicio 5: BoxPlot</font>**

# %% [markdown]
# <p><strong>Consigna:</strong> Utiliza los siguientes datos de la duración de llamadas telefónicas en minutos para crear un box plot que resuma las duraciones.</p>
# <ul>
#     <li><strong>Duración de llamadas (minutos):</strong> [5, 15, 20, 35, 10, 45, 50, 30, 25, 15, 10, 60]</li>
# </ul>

# %%
data = ({"Duración de llamada":[5, 15, 20, 35, 10, 45, 50, 30, 25, 15, 10, 60]})  # Tiempos de entrega en días


df3 = pd.DataFrame(data)
df3
# Out:
#     Duración de llamada
# 0                     5
# 1                    15
# 2                    20
# 3                    35
# 4                    10
# 5                    45
# 6                    50
# 7                    30
# 8                    25
# 9                    15
# 10                   10
# 11                   60

# %%
# Crear el gráfico box plot
fig = px.box(df3, y='Duración de llamada',
             title='Duración de las llamadas telefónicas',
             labels={'Duración de llamada': 'Duración de las llamadas (minutos)'},
             points='all',
             #color=['Duracion de llamada']) # Removing this line, as it's causing the error
             ) # Removing the color argument altogether solves the problem
# If you want to color the boxplot, you need to provide a list or array with the same length as the data.
# For instance, if you have a column in your dataframe that you want to use for coloring, you could use:
# color='column_name'
# Or if you want to color all boxes the same color, you could use:
# color_discrete_sequence=['cornflowerblue']  # replace with your desired color
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear el gráfico box plot
fig = px.box(df3, y='Duración de llamada',
             title='Duración de las llamadas telefónicas',
             labels={'Duración de llamada': 'Duración de las llamadas (minutos)'},
             points='all',
            color_discrete_sequence=['blue'],
             ) # Removing the color argument altogether solves the problem
# Mejorar el diseño del gráfico
fig.update_layout(
    title_font_size=18,
    xaxis_title_font_size=16,
    yaxis_title_font_size=16,
    template="plotly_white",  # Fondo blanco para mayor claridad
    showlegend=False
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  ## **<font color="DarkBlue">Ejercicio 6: Gráfico de Violín</font>**

# %% [markdown]
# <p><strong>Consigna:</strong> Utiliza los siguientes datos sobre el tiempo que los estudiantes dedican al estudio para crear un gráfico de violín que muestre la distribución del tiempo de estudio.</p>
# <ul>
#     <li><strong>Tiempo de estudio (horas por semana):</strong> [5, 10, 15, 20, 10, 5, 25, 30, 15, 20, 10, 5]</li>
# </ul>

# %%
import pandas as pd

# Datos
data1 = {"Tiempos de estudio": [5, 10, 15, 20, 10, 5, 25, 30, 15, 20, 10, 5]}

# Crear DataFrame
df4 = pd.DataFrame(data1)

# Visualizar DataFrame
print(df4)
# Out:
#     Tiempos de estudio
# 0                    5
# 1                   10
# 2                   15
# 3                   20
# 4                   10
# 5                    5
# 6                   25
# 7                   30
# 8                   15
# 9                   20
# 10                  10
# 11                   5

# %%
px.violin(df4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear el gráfico de violín con Plotly
fig = px.violin(df4,
                ##y=['Tiempo de estudio'],
                ###box=True,  # Mostrar un box plot dentro del gráfico de violín
                ###points='all',  # Mostrar todos los puntos de datos
                title='Distribucion de Tiempo de Estudio',
                ###labels={'Tiempo de estudio': 'Tiempo de estudio (horas por semnana)'},
                ##color=['Tiempo de estudio'],  # Colorear por segmento
                ##template="plotly_white"  # Fondo blanco para mayor claridad
                )

# Mejorar el diseño del gráfico
fig.update_layout(
    title_font_size=18,
    yaxis_title="Tiempo de estudio",
    xaxis_title="Segmento de Cliente",
    yaxis_title_font_size=16,
    xaxis_title_font_size=16,
    violingap=0.5  # Espacio entre los gráficos de violín
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <p align="center"><b>
# 💗
# <font color="DarkBlue">
# Hemos llegado al final de nuestra ejercitación en colab, a seguir ejercitando...
# </font>
# </p>
