# %% [markdown]
#  # **<font color="DarkBlue">Ingesta de datos, almacenamiento y formatos de archivos 🐼 </font>**

# %% [markdown]
# <p align="center">
# <img src="https://pandas.pydata.org/static/img/pandas_mark.svg" width="50">
# </p>

# %% [markdown]
# https://pandas.pydata.org/

# %% [markdown]
#  # **<font color="DarkBlue">Definiciones</font>**

# %% [markdown]
# <p align="justify"> 🚀 La <b>ingesta de datos</b> es el primer paso en el análisis de datos, donde se capturan datos desde diferentes fuentes para ser procesados y analizados. En el contexto de negocios, es común obtener datos desde archivos CSV, Excel, bases de datos o APIs. Pandas, junto con Google Colab, permite una ingesta rápida y eficiente, facilitando la manipulación de grandes volúmenes de información.

# %% [markdown]
# <p align="justify"> 🚀 El <b>almacenamiento</b> es crucial después de manipular o procesar los datos. Una vez que se han realizado cálculos o transformaciones en los datos, es necesario guardarlos en un formato adecuado para su consulta futura o para generar informes que apoyen las decisiones empresariales. Pandas permite almacenar los datos en diferentes formatos como CSV, Excel y JSON.

# %% [markdown]
# <p align="justify"> 🚀 El <b>formato de archivos</b> determina cómo los datos se guardan y cómo pueden ser compartidos o utilizados en diferentes sistemas. Los formatos más comunes incluyen CSV, Excel y JSON, cada uno adecuado para diferentes necesidades. CSV es ideal para grandes volúmenes de datos tabulares, Excel para informes más personalizados y JSON para intercambio de datos entre aplicaciones.

# %% [markdown]
#  # **<font color="DarkBlue">Ingesta de datos</font>**

# %%
import pandas as pd

# %% [markdown]
#  ## **<font color="DarkBlue">Lectura de una planilla Excel</font>**

# %% [markdown]
# <p align="justify">
# La ingesta de datos de Excel suele utilizarse porque este formato es ampliamente utilizado para gestionar bases de datos, reportes financieros, listas de inventarios, entre otros usos que se pueden encontrar.
# <br><br>
# Pandas ofrece una forma eficiente de realizar la ingesta de datos desde una planilla Excel mediante el método <code>pd.read_excel()</code>. Este método permite cargar los datos de uno o más archivos Excel en un DataFrame, la estructura de datos tabular de Pandas que facilita la manipulación y análisis de información.
# <br><br>
# En el siguiente ejemplo, vamos a ingestar una planilla Excel que está alojada en GitHub.

# %%
provincia = pd.read_excel("https://github.com/cristiandarioortegayubro/BDS/blob/main/datasets/maestro-provincias.xlsx?raw=true")

# %% [markdown]
# <p align="justify"> 🤯 Para poder ingestar un archivo excel desde GitHub, al final del nombre del archivo debe agregarse <code>?raw=true</code>

# %%
provincia
# Out:
#    sucursales_provincia            provincia
# 0                  AR-C                 CABA
# 1                  AR-B         Buenos Aires
# 2                  AR-K            Catamarca
# 3                  AR-H                Chaco
# 4                  AR-U               Chubut
# 5                  AR-X              Córdoba
# 6                  AR-W           Corrientes
# 7                  AR-E           Entre Ríos
# 8                  AR-P              Formosa
# 9                  AR-Y                Jujuy
# 10                 AR-L             La Pampa
# 11                 AR-F             La Rioja
# 12                 AR-M              Mendoza
# 13                 AR-N             Misiones
# 14                 AR-Q              Neuquén
# 15                 AR-R            Río Negro
# 16                 AR-A                Salta
# 17                 AR-J             San Juan
# 18                 AR-D             San Luis
# 19                 AR-Z           Santa Cruz
# 20                 AR-S             Santa Fe
# 21                 AR-G  Santiago del Estero
# 22                 AR-V     Tierra del Fuego
# 23                 AR-T              Tucumán

# %% [markdown]
#  ## **<font color="DarkBlue">Lectura de un archivo CSV</font>**

# %%
comercio = pd.read_csv("https://github.com/cristiandarioortegayubro/BDS/blob/main/datasets/comercio.csv?raw=true", sep="|")

# %%
productos = pd.read_csv("https://github.com/cristiandarioortegayubro/BDS/blob/main/datasets/productos.csv?raw=true", sep="|")

# %%
sucursales = pd.read_csv("https://github.com/cristiandarioortegayubro/BDS/blob/main/datasets/sucursales.csv?raw=true", sep="|")

# %%
comercio
# Out:
#                                        id_comercio  id_bandera  comercio_cuit  \
# 0                                                3         1.0   3.051619e+10
# 1  Ultima actualizacion: 2024-10-01T16:00:01-03:00         NaN            NaN
#
#     comercio_razon_social comercio_bandera_nombre  comercio_bandera_url  \
# 0  DEHEZA S.A.I.C.F. e I.  DEHEZA S.A.I.C.F. e I.                   NaN
# 1                     NaN                     NaN                   NaN
#
#   comercio_ultima_actualizacion  comercio_version_sepa
# 0     2024-10-01T16:00:02-03:00                    1.0
# 1                           NaN                    NaN

# %% [markdown]
# <p align="justify"> 👀 Ahora vamos a desactivar la notación científica en los datos numericos, para que el CUIT lo muestre como tiene que ser...

# %%
# Desactivar la notación científica para los números flotantes
pd.set_option('display.float_format', '{:.0f}'.format)

# %%
comercio
# Out:
#                                        id_comercio  id_bandera  comercio_cuit  \
# 0                                                3           1    30516186670
# 1  Ultima actualizacion: 2024-10-01T16:00:01-03:00         NaN            NaN
#
#     comercio_razon_social comercio_bandera_nombre  comercio_bandera_url  \
# 0  DEHEZA S.A.I.C.F. e I.  DEHEZA S.A.I.C.F. e I.                   NaN
# 1                     NaN                     NaN                   NaN
#
#   comercio_ultima_actualizacion  comercio_version_sepa
# 0     2024-10-01T16:00:02-03:00                      1
# 1                           NaN                    NaN

# %%
productos.head()
# Out:
#   id_comercio  id_bandera  id_sucursal   id_producto  productos_ean  \
# 0           3           1            3 7791813421580              1
# 1           3           1            3 7798260050226              1
# 2           3           1            3         23897              0
# 3           3           1            3 7790580109882              1
# 4           3           1            3 7790040133594              1
#
#                  productos_descripcion  productos_cantidad_presentacion  \
# 0                  7UP FREE PET X 1.5L                                1
# 1          ACEITE DE COCO NEUTRO 360ML                              360
# 2            AFEITADORA BIC COMFORT  3                                1
# 3  AGUILA EXTRAFINO 60% CACAO X 150 GR                                1
# 4       AGUILA MINITORTA BROWNIE X 72G                                1
#
#   productos_unidad_medida_presentacion productos_marca  \
# 0                               unidad
# 1                                  cm3
# 2                               unidad
# 3                               unidad
# 4                               unidad
#
#    productos_precio_lista  productos_precio_referencia  \
# 0                    2700                         2700
# 1                     740                         2056
# 2                     820                          820
# 3                    6790                         6790
# 4                    1650                         1650
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                              1                             unidad
# 1                              1                                  l
# 2                              1                             unidad
# 3                              1                             unidad
# 4                              1                             unidad
#
#    productos_precio_unitario_promo1  productos_leyenda_promo1  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN

# %%
sucursales.head()
# Out:
#   id_comercio  id_bandera  id_sucursal     sucursales_nombre sucursales_tipo  \
# 0           3           1            2              ACASSUSO    Autoservicio
# 1           3           1            3                 RIVER    Autoservicio
# 2           3           1           29               CABILDO    Autoservicio
# 3           3           1           31            CENTENARIO    Autoservicio
# 4           3           1           36  LINCOLN Y NUEVA YORK    Autoservicio
#
#   sucursales_calle  sucursales_numero  sucursales_latitud  \
# 0   AV. LIBERTADOR              15301                 -34
# 1    AV. F.ALCORTA               7786                 -35
# 2          CABILDO               4701                 -35
# 3   AV. F. ALCORTA               3099                 -35
# 4      AV. LINCOLN               3999                 -35
#
#    sucursales_longitud  sucursales_observaciones  ...  \
# 0                  -59                       NaN  ...
# 1                  -58                       NaN  ...
# 2                  -58                       NaN  ...
# 3                  -58                       NaN  ...
# 4                  -59                       NaN  ...
#
#   sucursales_codigo_postal sucursales_localidad sucursales_provincia  \
# 0                     1641             ACASSUSO                 AR-B
# 1                     1428      CAPITAL FEDERAL                 AR-C
# 2                     1429      CAPITAL FEDERAL                 AR-C
# 3                     1425      CAPITAL FEDERAL                 AR-C
# 4                     1419      CAPITAL FEDERAL                 AR-C
#
#   sucursales_lunes_horario_atencion sucursales_martes_horario_atencion  \
# 0                     00:00 a 24:00                      00:00 a 24:00
# 1                     00:00 a 24:00                      00:00 a 24:00
# 2                     00:00 a 24:00                      00:00 a 24:00
# 3                     00:00 a 24:00                      00:00 a 24:00
# 4                     00:00 a 24:00                      00:00 a 24:00
#
#   sucursales_miercoles_horario_atencion sucursales_jueves_horario_atencion  \
# 0                         00:00 a 24:00                      00:00 a 24:00
# 1                         00:00 a 24:00                      00:00 a 24:00
# 2                         00:00 a 24:00                      00:00 a 24:00
# 3                         00:00 a 24:00                      00:00 a 24:00
# 4                         00:00 a 24:00                      00:00 a 24:00
#
#   sucursales_viernes_horario_atencion sucursales_sabado_horario_atencion  \
# 0                       00:00 a 24:00                      00:00 a 24:00
# 1                       00:00 a 24:00                      00:00 a 24:00
# 2                       00:00 a 24:00                      00:00 a 24:00
# 3                       00:00 a 24:00                      00:00 a 24:00
# 4                       00:00 a 24:00                      00:00 a 24:00
#
#   sucursales_domingo_horario_atencion
# 0                       00:00 a 24:00
# 1                       00:00 a 24:00
# 2                       00:00 a 24:00
# 3                       00:00 a 24:00
# 4                       00:00 a 24:00
#
# [5 rows x 21 columns]

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DarkBlue">
# Hemos llegado al final de nuestro colab de Pandas, a seguir codeando...
# </font>
# </p>
